# %%
import numpy as np
from numpy import random
import math

class Teams:
    def __init__(self):
        self.Tname = {
            "a",  # 0
            "b",  # 1
            "c",  # 2
        }
        self.SlotTime = np.array([
            ["xxxxxxx"], ["xxxxxxx"],
            ["xxxxxxx"], ["xxxxxxx"],
            ["xxxxxxx"], ["xxxxxxx"],
            ["xxxxxxx"], ["xxxxxxx"],
            ["xxxxxxx"], ["xxxxxxx"]
        ])
        self.SlotTimeWeek = np.array([self.SlotTime for _ in range(len(self.Tname))]  # Ex . for five rooms
                                     )
    def getTeamsName(self):
        return self.Tname

    def getTimeWeek(self):
        return self.SlotTimeWeek

class CoursesWorkload:
    def __init__(self):
        self.CWL = np.array([   # WorkNumber , Details , Days, Teams
            ["001","work 1", -1, -1],
            ["002","work 2", -1, -1],
            ["003","work 3", -1, -1],
            ["004","work 4", -1, -1],
            ["005","work 5", -1, -1],
            ["006","work 6", -1, -1],
            ["007","work 7", -1, -1],
            ["008","work 8", -1, -1],
            ["009","work 9", -1, -1],
            ["010","work 10", -1, -1],
            ["011","work 11", -1, -1],
            ["012","work 12", -1, -1],
            ["013","work 13", -1, -1],
            ["014","work 14", -1, -1],
            ["015","work 15", -1, -1],
            ["016","work 16", -1, -1],
            ["017","work 17", -1, -1],
            ["018","work 18", -1, -1],
            ["019","work 19", -1, -1],
            ["020","work 20", -1, -1],
           
        ])

    def getCourseWorkload(self):
        return self.CWL

# %%
# ------ Main Class ------

def Scheduling(Rm, CWL):
    
    a1 = []
    a2 = []
    a3 = []
    a4 = []
    
    for i in range(len(CWL)):
        rdRoom = random.randint(0, len(Rm))
        rdSlot = random.randint(0, len(Rm[0])-1)
        while (Rm[rdRoom, rdSlot] != "xxxxxxx"):
            rdRoom = random.randint(0, len(Rm)-1)
            rdSlot = random.randint(0, len(Rm[0])-1)
        CWL[i, 2] = rdRoom  # Cwl[i,2] = random.randint(0,len(Rm)-1)
        CWL[i, 3] = rdSlot  # Cwl[i,3] = random.randint(0,len(Rm[0])-1)
        # Rm[int(Cwl[i,2]), int(Cwl[i,3])] = Cwl[i,0]
        Rm[int(CWL[i, 2]), int(CWL[i, 3])] = CWL[i, 0]
        
        if int(CWL[i, 2]) == 0:
            a1.append(int(CWL[i, 2]))
        if int(CWL[i, 2]) == 1:
            a2.append(int(CWL[i, 2]))
        if int(CWL[i, 2]) == 2:
            a3.append(int(CWL[i, 2]))
            
    a4.append(len(a1))
    a4.append(len(a2))
    a4.append(len(a3))
    
    return a4
        
        

def DisplayWork(Rm, CWL):
    count_of_work=[]
    for i in range(len(Rm)):
        count=0
        print()
        for sl in range(len(Rm[i])):
            if Rm[i,sl] != ['xxxxxxx']:
                    count+=1
            print(Rm[i,sl],end=" ")
            if sl%2 == 1:
                print()
        count_of_work.append(count)
    return count_of_work

T = Teams()
C = CoursesWorkload()
S = Scheduling( T.getTimeWeek(), C.getCourseWorkload())
min = int(len(C.getCourseWorkload())/len(T.getTimeWeek()))
max = math.ceil(len(C.getCourseWorkload())/len(T.getTimeWeek()))
while True:
    if (S[0] == min or S[0] <= max) and (S[1] == min or S[1] <= max) and (S[2] == min or S[2] <= max):
        break
    else:
        T = Teams()
        S = Scheduling( T.getTimeWeek(), C.getCourseWorkload())
        
D = DisplayWork(T.getTimeWeek(),C.getCourseWorkload())
print()
print("work : ",len(C.getCourseWorkload()))
print("work_assign : ",D)
print("----------------------------")
# Out:
# ['xxxxxxx'] ['018']
# ['004'] ['xxxxxxx']
# ['011'] ['014']
# ['006'] ['013']
# ['015'] ['xxxxxxx']
#
# ['xxxxxxx'] ['017']
# ['xxxxxxx'] ['016']
# ['007'] ['003']
# ['020'] ['005']
# ['012'] ['xxxxxxx']
#
# ['001'] ['010']
# ['009'] ['002']
# ['xxxxxxx'] ['008']
# ['xxxxxxx'] ['xxxxxxx']
# ['019'] ['xxxxxxx']
#
# work :  20
# work_assign :  [7, 7, 6]
# ----------------------------
